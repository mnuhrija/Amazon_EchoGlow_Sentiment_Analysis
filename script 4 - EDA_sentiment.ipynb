# %% [markdown]
# ## Import Library

# %%
import pandas as pd

# %% [markdown]
# ## Load Data

# %%
df = pd.read_csv('amazon_EchoGlow_sentiment.csv')
df
# Out:
#               Username               Stars  \
# 0       Adam S. Walter  2.0 out of 5 stars
# 1            Samie May  2.0 out of 5 stars
# 2              Michael  3.0 out of 5 stars
# 3      Matthew Studney  4.0 out of 5 stars
# 4          Veronica44h  5.0 out of 5 stars
# ..                 ...                 ...
# 995           Elissa81  5.0 out of 5 stars
# 996          Super Dad  5.0 out of 5 stars
# 997  Sondra M. DeVries  5.0 out of 5 stars
# 998         Kathryn S.  5.0 out of 5 stars
# 999     Pauline Okrent  5.0 out of 5 stars
#
#                                            Review Text  \
# 0    No parents were consulted during the making or...
# 1    UPDATE: I've had this for another 24 hours and...
# 2    First off, limiting this product marketing to ...
# 3    I bought this specifically as a wake up (rathe...
# 4    My review this is a solid 5 out of 5 for what ...
# ..                                                 ...
# ...

# %%
helpfull_review = df[df['Review Usefulness'] != 'No Data']
helpfull_review['Review Usefulness'] = helpfull_review['Review Usefulness'].str.split(' ')

Usefulness = []
for i in helpfull_review['Review Usefulness']:
    i = i[0]
    Usefulness.append(i)

helpfull_review['Review Usefulness'] = Usefulness
helpfull_review
# Out:
# C:\Users\Rija\AppData\Local\Temp/ipykernel_7756/3990623044.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   helpfull_review['Review Usefulness'] = helpfull_review['Review Usefulness'].str.split(' ')
# C:\Users\Rija\AppData\Local\Temp/ipykernel_7756/3990623044.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   helpfull_review['Review Usefulness'] = Usefulness
#             Username               Stars  \
# 0     Adam S. Walter  2.0 out of 5 stars
# ...

# %%
df['Random'] = 1

df.groupby(['Stars', 'Sentiment Label'])['Random'].count().reset_index()
# Out:
# C:\Users\Rija\AppData\Local\Temp/ipykernel_7756/3418332324.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   helpfull_review['Random'] = 1
#                 Stars Sentiment Label  Random
# 0  1.0 out of 5 stars        NEGATIVE      54
# 1  1.0 out of 5 stars        POSITIVE       3
# 2  2.0 out of 5 stars        NEGATIVE      16
# 3  2.0 out of 5 stars        POSITIVE       2
# 4  3.0 out of 5 stars        NEGATIVE      15
# 5  3.0 out of 5 stars        POSITIVE       6
# 6  4.0 out of 5 stars        NEGATIVE      11
# 7  4.0 out of 5 stars        POSITIVE      16
# 8  5.0 out of 5 stars        NEGATIVE      13
# 9  5.0 out of 5 stars        POSITIVE      66

# %%
five_star_negative = df[(df['Stars'] == "5.0 out of 5 stars") & (df['Sentiment Label'] == 'NEGATIVE')]
five_star_negative
# Out:
#               Username               Stars  \
# 5           Jon Almada  5.0 out of 5 stars
# 13        Jim Di Liddo  5.0 out of 5 stars
# 34            Pat Cain  5.0 out of 5 stars
# 40   Patrick Dragonite  5.0 out of 5 stars
# 74   Matthew D. Cowles  5.0 out of 5 stars
# ..                 ...                 ...
# 893            tvjames  5.0 out of 5 stars
# 898           stormcat  5.0 out of 5 stars
# 908            Matthew  5.0 out of 5 stars
# 920          H. Llanes  5.0 out of 5 stars
# 962             guille  5.0 out of 5 stars
#
#                                            Review Text  \
# 5    I was one of the early purchasers of this ligh...
# 13   I have one sitting on my nightstand to give th...
# 34   So I bought this light knowing exactly what I ...
# 40   We got these as Okay to Wake lights. Needed so...
# 74   I don't get why other reviewers don't like thi...
# ..                                                 ...
# ...

# %%
five_star_negative.iloc[20,2]
# Out:
# 'Didn’t realize this was JUST an accessory to the echo itself. Long story short I have a baby due late august and was going to use the glow in the nursery, well my lovely rabbit decided the cord was going to be a snack and ate straight through it. Tried to buy a replacement cord and it you can’t even replace the cord. I’m so sad because it’s such a great night light! I bought as a 2 pc set with the Echo Kids. My fault about the rabbit but I just wish the cord was replaceable or could be bought separately vs having to purchase a whole new Echo Glow at $30 vs the $15 I paid for the set.'
